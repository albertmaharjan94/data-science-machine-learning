# %% [markdown]
# # Data manipulation

# %% [markdown]
# ## Part 1

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
car_sales = pd.read_csv("7.1 car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# lower case ~ string function runs in whole column
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales_missing = pd.read_csv("9.2 car-sales-missing-data.csv")

# %%
# NaN refers to missing value or null
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# inplace can reassign the view
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace = True)
# another approach
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
# drop NaN rows
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("9.2 car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-dropped-to-csv.csv")

# %% [markdown]
# ## Part 2

# %%
# column from series
seats_column = pd.Series([5,5,5,5,5])

# %%
# manipulate new column with a series
car_sales["Seats"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    NaN
# 6   honda   Blue          45698      4   $7,500.00    NaN
# 7   honda   Blue          54738      4   $7,000.00    NaN
# 8  toyota  White          60000      4   $6,250.00    NaN
# 9  nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["Seats"].fillna(car_sales["Seats"].mean(), inplace= True)

# %%
# column form python list
fuel_economy = [7.5,9.5, 5.4, 4.4, 4.8, 3.2, 6.7, 8.9, 7.8, 10.11]
# this needs to be of exact lenght of the row count

# %%
car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   $4,000.00    5.0            7.50
# 1   honda    Red          87899      4   $5,000.00    5.0            9.50
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.40
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.40
# 4  nissan  White         213095      4   $3,500.00    5.0            4.80
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.20
# 6   honda   Blue          45698      4   $7,500.00    5.0            6.70
# 7   honda   Blue          54738      4   $7,000.00    5.0            8.90
# 8  toyota  White          60000      4   $6,250.00    5.0            7.80
# 9  nissan  White          31600      4   $9,700.00    5.0           10.11

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0            7.50
# 1   honda    Red          87899      4   $5,000.00    5.0            9.50
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.40
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.40
# 4  nissan  White         213095      4   $3,500.00    5.0            4.80
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.20
# 6   honda   Blue          45698      4   $7,500.00    5.0            6.70
# 7   honda   Blue          54738      4   $7,000.00    5.0            8.90
# 8  toyota  White          60000      4   $6,250.00    5.0            7.80
# 9  nissan  White          31600      4   $9,700.00    5.0           10.11
#
#    Total fuel used  Total fuel used (L)
# 0        11253.225            11253.225
# 1         8350.405             8350.405
# 2         1757.646             1757.646
# 3          491.876              491.876
# 4        10228.560            10228.560
# 5         3174.816             3174.816
# 6         3061.766             3061.766
# 7         4871.682             4871.682
# 8         4680.000             4680.000
# 9         3194.760             3194.760

# %%
# Create a column from single value
car_sales["Number of wheeles"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0            7.50
# 1   honda    Red          87899      4   $5,000.00    5.0            9.50
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.40
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.40
# 4  nissan  White         213095      4   $3,500.00    5.0            4.80
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.20
# 6   honda   Blue          45698      4   $7,500.00    5.0            6.70
# 7   honda   Blue          54738      4   $7,000.00    5.0            8.90
# 8  toyota  White          60000      4   $6,250.00    5.0            7.80
# 9  nissan  White          31600      4   $9,700.00    5.0           10.11
#
#    Total fuel used  Total fuel used (L)  Number of wheeles
# 0        11253.225            11253.225                  4
# 1         8350.405             8350.405                  4
# 2         1757.646             1757.646                  4
# 3          491.876              491.876                  4
# 4        10228.560            10228.560                  4
# 5         3174.816             3174.816                  4
# 6         3061.766             3061.766                  4
# 7         4871.682             4871.682                  4
# 8         4680.000             4680.000                  4
# 9         3194.760             3194.760                  4

# %%
car_sales["Road safety"] = True

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                   object
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used        float64
# Total fuel used (L)    float64
# Number of wheeles        int64
# Road safety               bool
# dtype: object

# %%
# axis 0 = rows, axis 1 = column
car_sales = car_sales.drop("Total fuel used", axis = 1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0            7.50
# 1   honda    Red          87899      4   $5,000.00    5.0            9.50
# 2  toyota   Blue          32549      3   $7,000.00    5.0            5.40
# 3     bmw  Black          11179      5  $22,000.00    5.0            4.40
# 4  nissan  White         213095      4   $3,500.00    5.0            4.80
# 5  toyota  Green          99213      4   $4,500.00    5.0            3.20
# 6   honda   Blue          45698      4   $7,500.00    5.0            6.70
# 7   honda   Blue          54738      4   $7,000.00    5.0            8.90
# 8  toyota  White          60000      4   $6,250.00    5.0            7.80
# 9  nissan  White          31600      4   $9,700.00    5.0           10.11
#
#    Total fuel used (L)  Number of wheeles  Road safety
# 0            11253.225                  4         True
# 1             8350.405                  4         True
# 2             1757.646                  4         True
# 3              491.876                  4         True
# 4            10228.560                  4         True
# 5             3174.816                  4         True
# 6             3061.766                  4         True
# 7             4871.682                  4         True
# 8             4680.000                  4         True
# 9             3194.760                  4         True

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$,\,\.]",'').astype(int)/100
# Out:
# <ipython-input-29-b2e5dc702f43>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\$,\,\.]",'').astype(int)/100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0            7.50
# 1   honda    Red          87899      4   5000.0    5.0            9.50
# 2  toyota   Blue          32549      3   7000.0    5.0            5.40
# 3     bmw  Black          11179      5  22000.0    5.0            4.40
# 4  nissan  White         213095      4   3500.0    5.0            4.80
# 5  toyota  Green          99213      4   4500.0    5.0            3.20
# 6   honda   Blue          45698      4   7500.0    5.0            6.70
# 7   honda   Blue          54738      4   7000.0    5.0            8.90
# 8  toyota  White          60000      4   6250.0    5.0            7.80
# 9  nissan  White          31600      4   9700.0    5.0           10.11
#
#    Total fuel used (L)  Number of wheeles  Road safety
# 0            11253.225                  4         True
# 1             8350.405                  4         True
# 2             1757.646                  4         True
# 3              491.876                  4         True
# 4            10228.560                  4         True
# 5             3174.816                  4         True
# 6             3061.766                  4         True
# 7             4871.682                  4         True
# 8             4680.000                  4         True
# 9             3194.760                  4         True

# %% [markdown]
# ## Part 3

# %%
# sample shuffles orders, frac is percentage of data
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3   7000.0    5.0            5.40
# 9  nissan  White          31600      4   9700.0    5.0           10.11
# 1   honda    Red          87899      4   5000.0    5.0            9.50
# 6   honda   Blue          45698      4   7500.0    5.0            6.70
# 5  toyota  Green          99213      4   4500.0    5.0            3.20
# 0  toyota  White         150043      4   4000.0    5.0            7.50
# 4  nissan  White         213095      4   3500.0    5.0            4.80
# 8  toyota  White          60000      4   6250.0    5.0            7.80
# 3     bmw  Black          11179      5  22000.0    5.0            4.40
# 7   honda   Blue          54738      4   7000.0    5.0            8.90
#
#    Total fuel used (L)  Number of wheeles  Road safety
# 2             1757.646                  4         True
# 9             3194.760                  4         True
# 1             8350.405                  4         True
# 6             3061.766                  4         True
# 5             3174.816                  4         True
# 0            11253.225                  4         True
# 4            10228.560                  4         True
# 8             4680.000                  4         True
# 3              491.876                  4         True
# 7             4871.682                  4         True

# %%
# reset index
car_sales_shuffled.reset_index(drop = True, inplace= True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  nissan  White         213095      4   3500.0    5.0            4.80
# 1  toyota   Blue          32549      3   7000.0    5.0            5.40
# 2   honda    Red          87899      4   5000.0    5.0            9.50
# 3     bmw  Black          11179      5  22000.0    5.0            4.40
# 4   honda   Blue          45698      4   7500.0    5.0            6.70
# 5  nissan  White          31600      4   9700.0    5.0           10.11
# 6   honda   Blue          54738      4   7000.0    5.0            8.90
# 7  toyota  Green          99213      4   4500.0    5.0            3.20
# 8  toyota  White          60000      4   6250.0    5.0            7.80
# 9  toyota  White         150043      4   4000.0    5.0            7.50
#
#    Total fuel used (L)  Number of wheeles  Road safety
# 0            10228.560                  4         True
# 1             1757.646                  4         True
# 2             8350.405                  4         True
# 3              491.876                  4         True
# 4             3061.766                  4         True
# 5             3194.760                  4         True
# 6             4871.682                  4         True
# 7             3174.816                  4         True
# 8             4680.000                  4         True
# 9            11253.225                  4         True

# %%
# lambda aply
car_sales_shuffled["Odometer (KM)"] = car_sales_shuffled["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
# opeartion alternatives
car_sales_shuffled["Odometer (KM)"] = car_sales_shuffled["Odometer (KM)"]*1.6

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  nissan  White       213095.0      4   3500.0    5.0            4.80
# 1  toyota   Blue        32549.0      3   7000.0    5.0            5.40
# 2   honda    Red        87899.0      4   5000.0    5.0            9.50
# 3     bmw  Black        11179.0      5  22000.0    5.0            4.40
# 4   honda   Blue        45698.0      4   7500.0    5.0            6.70
# 5  nissan  White        31600.0      4   9700.0    5.0           10.11
# 6   honda   Blue        54738.0      4   7000.0    5.0            8.90
# 7  toyota  Green        99213.0      4   4500.0    5.0            3.20
# 8  toyota  White        60000.0      4   6250.0    5.0            7.80
# 9  toyota  White       150043.0      4   4000.0    5.0            7.50
#
#    Total fuel used (L)  Number of wheeles  Road safety
# 0            10228.560                  4         True
# 1             1757.646                  4         True
# 2             8350.405                  4         True
# 3              491.876                  4         True
# 4             3061.766                  4         True
# 5             3194.760                  4         True
# 6             4871.682                  4         True
# 7             3174.816                  4         True
# 8             4680.000                  4         True
# 9            11253.225                  4         True
